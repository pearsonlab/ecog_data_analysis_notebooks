# %%
from __future__ import print_function

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import json
import os
import mne
import copy

import ecogtools

# %%
# %matplotlib inline

# %%
patient_num = "2003"

channels = ['LTG1', 'LTG2','LTG3','LTG4','LTG5',
           'LTG6','LTG7','LTG8','LTG9','LTG10',
           'LTG11','LTG12','LTG13','LTG14','LTG15',
           'LTG16','LTG17','LTG18','LTG19','LTG20',
           'LTG21','LTG22','LTG23','LTG24','LTG25',
           'LTG26','LTG27','LTG28','LTG29','LTG30',
           'LTG31','LTG32']

# %%
data = ecogtools.bio_motion_task_single_trial(patient_num)
# Out:
# Extracting edf Parameters from patient_2003/john_2003.edf...
# Setting channel info structure...
# Creating Raw.info structure...
# Ready.

# %%
# Get the times for task from behavioral data
tmin = int(data.trig_and_behav.loc[0, 'trigger_time']-10)
tmax = int(data.trig_and_behav.loc[107, 'trigger_time']+10)

# Get only physiology data that we actually want to look at for task.
data.phys.crop(tmin=tmin, tmax=tmax)
# Out:
# <RawEDF  |  john_2003.edf, n_channels x n_times : 129 x 984001 (492.0 sec), ~221 kB, data not loaded>

# %%
# Load data and pick only channels that we care about.
data.phys.load_data()
data.phys.pick_channels(channels)
# Out:
# Reading 0 ... 984000  =      0.000 ...   492.000 secs...
# <RawEDF  |  john_2003.edf, n_channels x n_times : 32 x 984001 (492.0 sec), ~240.3 MB, data loaded>

# %%
# Create epochs object for trial viz and averaging.
data.initialize_epochs_object(channels, tmin=-6., tmax=6., baseline=None)
# Out:
# 132 matching events found
# 0 projection items activated
# Loading data for 132 events and 24001 original time points ...
# 30 bad epochs dropped

# %%
# Create evoked for Question Start
bio_dir_evoked = data.create_evoked("Direction-Bio/trial_type")
contr_dir_evoked = data.create_evoked("Direction-Control/trial_type")
QS_evoked = mne.combine_evoked([contr_dir_evoked, bio_dir_evoked], weights=[1, -1])

# %%
# BANDPASS FILTER: Define frequencies, cycles and bandwidth
freqs = np.linspace(50, 150, 25)
n_cycles = freqs/2.0
time_bandwidth = 8.0

# %%
# Calculate power for Q Start high gamma ()
contr_dir_power = mne.time_frequency.tfr_multitaper(data.epochs['Direction-Control/trial_type'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
bio_dir_power = mne.time_frequency.tfr_multitaper(data.epochs['Direction-Bio/trial_type'], freqs=freqs, n_cycles=n_cycles,
                       time_bandwidth=time_bandwidth, return_itc=False)
QS_power = data.compute_diff_power(contr_dir_power, bio_dir_power)

# %%
# Copy data class for Filter-Hilbert Transform
data_filt = copy.copy(data)
data_filt.phys.filter(80, 160)
data_filt.phys.apply_hilbert(envelope=True)
# Out:
# Setting up band-pass filter from 80 - 1.6e+02 Hz
# l_trans_bandwidth chosen to be 20.0 Hz
# h_trans_bandwidth chosen to be 40.0 Hz
# Filter length of 660 samples (0.330 sec) selected
# <RawEDF  |  john_2003.edf, n_channels x n_times : 32 x 984001 (492.0 sec), ~240.3 MB, data loaded>

# %%
# New epochs object for filtered/HT data
data_filt.initialize_epochs_object(channels, tmin=-6., tmax=6., baseline=None)
# Out:
# 132 matching events found
# 0 projection items activated
# Loading data for 132 events and 24001 original time points ...
# 30 bad epochs dropped

# %%
# Evoked Power for Question Start sad-neutral/happy
bio_dir_evoked_filt = data_filt.create_evoked("Direction-Bio/trial_type")
contr_dir_evoked_filt = data_filt.create_evoked("Direction-Control/trial_type")
QS_filt = mne.combine_evoked([contr_dir_evoked_filt, bio_dir_evoked_filt], weights = [1, -1])

# %%
# Define frequencies, cycles and bandwidth
freqs = np.geomspace(1, 50, 50)
n_cycles = freqs/2.0
print(freqs)
# Out:
# [  1.           1.08311073   1.17312885   1.27062844   1.37623129
#    1.49061088   1.61449663   1.74867862   1.89401257   2.05142534
#    2.22192079   2.40658624   2.60659937   2.82323575   3.05787692
#    3.3120193    3.58728363   3.88542538   4.20834591   4.5581046
#    4.93693199   5.347244     5.79165734   6.27300619   6.7943603
#    7.35904453   7.97066007   8.63310743   9.35061127  10.12774737
#   10.96947182  11.88115261  12.86860384  13.93812287  15.0965304
#   16.35121402  17.71017531  19.18208087  20.77631756  22.50305243
#   24.37329749  26.39897997  28.5930184   30.96940496  33.54329473
#   36.33110236  39.3506067   42.62106425  46.1633319   50.        ]

# %%
# Calculate power for Question Start low freq
low_contr_dir_power = mne.time_frequency.tfr_morlet(data.epochs['Direction-Control/trial_type'], freqs=freqs, n_cycles=n_cycles,
                    return_itc=False)
low_bio_dir_power = mne.time_frequency.tfr_morlet(data.epochs['Direction-Bio/trial_type'], freqs=freqs, n_cycles=n_cycles,
                    return_itc=False)
low_QS_power = data.compute_diff_power(low_contr_dir_power, low_bio_dir_power)

# %%
# Copy data class for Filter-Hilbert Transform
data_filt = copy.copy(data)
data_filt.phys.filter(1, 80)
data_filt.phys.apply_hilbert(envelope=True)
# Out:
# Setting up band-pass filter from 1 - 80 Hz
# l_trans_bandwidth chosen to be 1.0 Hz
# h_trans_bandwidth chosen to be 20.0 Hz
# Filter length of 13200 samples (6.600 sec) selected
# <RawEDF  |  john_2003.edf, n_channels x n_times : 32 x 984001 (492.0 sec), ~240.3 MB, data loaded>

# %%
# New epochs object for filtered/HT data
data_filt.initialize_epochs_object(channels, tmin=-6., tmax=6., baseline=None)
# Out:
# 132 matching events found
# 0 projection items activated
# Loading data for 132 events and 24001 original time points ...
# 30 bad epochs dropped

# %% [markdown]
# Plots

# %%
# Choose channels and define parameters for all functions
channel_of_interest = "LTG31"
index = channels.index(channel_of_interest)
COI = [index]

# Times and baseline periods for QS/TR
# Times and baseline periods for QS/TR
QS_times = {"tmin":-1., "tmax":4.}
TR_times = {"tmin":-4., "tmax":1.}
QS_baseline = (-1., 0)
TR_baseline = (0., .5)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 123

# %%
# %matplotlib inline

# %%
# Times and baseline periods for QS

for channel in channels:
    channel_of_interest = channel
    index = channels.index(channel_of_interest)
    COI = [index]
    
    f, axes = plt.subplots(4, 3, figsize=(15,12))

    bio_dir_evoked.crop(**QS_times).plot(COI, axes=axes[0,0], show=False, titles="Bio Motion");
    contr_dir_evoked.crop(**QS_times).plot(COI, axes=axes[0, 1], show=False, titles="Control Motion");
    QS_evoked.crop(**QS_times).plot(COI, axes=axes[0, 2], show=False, titles="COMBINED");

    bio_dir_power.plot(COI, baseline=QS_baseline, mode='ratio', dB=True, vmin=-5., vmax=5., **QS_times, axes=axes[1, 0], show=False, colorbar=False);
    contr_dir_power.plot(COI, baseline=QS_baseline, mode='ratio', dB=True, vmin=-5., vmax=5., **QS_times, axes=axes[1, 1], show=False, colorbar=False);
    QS_power.plot(COI, baseline=QS_baseline, mode='ratio', dB=True, vmin=-5., vmax=5., **QS_times, axes=axes[1, 2], show=False, colorbar=False);

    low_bio_dir_power.plot(COI, baseline=QS_baseline, mode='ratio', dB=True, vmin=-5., vmax=5., **QS_times, axes=axes[2, 0], show=False, colorbar=False);
    low_contr_dir_power.plot(COI, baseline=QS_baseline, mode='ratio', dB=True, vmin=-5., vmax=5., **QS_times, axes=axes[2, 1], show=False, colorbar=False);
    low_QS_power.plot(COI, baseline=QS_baseline, mode='ratio', dB=True, vmin=-5., vmax=5., **QS_times, axes=axes[2, 2], show=False, colorbar=False);    
        
    bio_dir_evoked_filt.crop(**QS_times).plot(COI, axes=axes[3, 0], show=False);
    contr_dir_evoked_filt.crop(**QS_times).plot(COI, axes=axes[3, 1], show=False);
    QS_filt.crop(**QS_times).plot(COI, axes=axes[3, 2], show=False);

    f.savefig("patient_"+patient_num+'/Bio_Motion_plots/' + channel_of_interest + ".png")

# %%
data.trig_and_behav.to_csv('2003_data.csv')

# %%
data.epochs
# Out:
# <Epochs  |  n_events : 102 (all good), tmin : -6.0 (s), tmax : 6.0 (s), baseline : None, ~597.7 MB, data loaded,
#  'Direction-Bio/time_of_resp': 15, 'Direction-Bio/trial_type': 18, 'Direction-Control/time_of_resp': 16, 'Direction-Control/trial_type': 18, 'Instrumental-Bio/time_of_resp': 9, 'Instrumental-Bio/trial_type': 10, 'Instrumental-Control/time_of_resp': 7, 'Instrumental-Control/trial_type': 9>

# %%
data.trig_and_behav
# Out:
#                 action  correct_resp  is_type  resp_time response  \
# 0            Paint_45L         False     True        NaN  timeout
# 1            Paint_45L         False     True        NaN  timeout
# 2              Saw_45R         False    False   8.981997     left
# 3              Saw_45R         False    False   8.981997     left
# 4              Row_45L         False     True   7.482348    right
# 5              Row_45L         False     True   7.482348    right
# 6              Saw_0MM          True    False   3.588461     down
# 7              Saw_0MM          True    False   3.588461     down
# 8            Drive_45L         False     True   8.168387     down
# 9            Drive_45L         False     True   8.168387     down
# 10           Crawl_45R         False    False        NaN  timeout
# 11           Crawl_45R         False    False        NaN  timeout
# 12    Control_Walk_45L         False    False   7.483027    right
# 13    Control_Walk_45L         False    False   7.483027    right
# 14   Control_Drive_45R         False    False   5.565970     down
# 15   Control_Drive_45R         False    False   5.565970     down
# 16     Control_Saw_45R         False    False   7.182181     down
# 17     Control_Saw_45R         False    False   7.182181     down
# 18            Walk_45R          True    False   5.481877    right
# 19            Walk_45R          True    False   5.481877    right
# 20           Cycle_45L         False     True        NaN  timeout
# 21           Cycle_45L         False     True        NaN  timeout
# 22     Control_Row_45R         False    False   9.912066     left
# 23     Control_Row_45R         False    False   9.912066     left
# 24           Sweep_90R         False    False   5.150006     left
# 25           Sweep_90R         False    False   5.150006     left
# 26           Sweep_45R          True    False   5.248363    right
# 27           Sweep_45R          True    False   5.248363    right
# 28   Control_Crawl_45L         False    False        NaN  timeout
# 29   Control_Crawl_45L         False    False        NaN  timeout
# ..                 ...           ...      ...        ...      ...
# 114   Control_Walk_45R          True    False   5.224918    right
# 115   Control_Walk_45R          True    False   5.224918    right
# 116           Wave_0MM         False    False   6.857800     left
# 117           Wave_0MM         False    False   6.857800     left
# 118  Control_Drive_45R         False    False   7.706846     left
# 119  Control_Drive_45R         False    False   7.706846     left
# 120          Drive_45R         False     True   5.575838    right
# 121          Drive_45R         False     True   5.575838    right
# 122  Control_Paint_45L         False    False        NaN  timeout
# 123  Control_Paint_45L         False    False        NaN  timeout
# 124    Control_Saw_45R          True    False   7.872991    right
# 125    Control_Saw_45R          True    False   7.872991    right
# 126  Control_Paint_45R         False    False   3.626983     left
# 127  Control_Paint_45R         False    False   3.626983     left
# 128           Jump_0MM         False    False   3.061343     left
# 129           Jump_0MM         False    False   3.061343     left
# 130            Row_45L         False     True   6.839091    right
# 131            Row_45L         False     True   6.839091    right
# 132  Control_Sweep_45R         False    False        NaN  timeout
# 133  Control_Sweep_45R         False    False        NaN  timeout
# 134          Paint_45R         False     True        NaN  timeout
# 135          Paint_45R         False     True        NaN  timeout
# 136          Crawl_45R         False    False   4.060121     left
# 137          Crawl_45R         False    False   4.060121     left
# 138  Control_Cycle_45L          True    False   7.656527    right
# 139  Control_Cycle_45L          True    False   7.656527    right
# 140    Control_Row_45L         False    False        NaN  timeout
# 141    Control_Row_45L         False    False        NaN  timeout
# 142            Row_45R         False     True        NaN  timeout
# 143            Row_45R         False     True        NaN  timeout
#
#        trial_type  trigger_name  cpu_trigger_time        task  trigger  \
# 0       Direction     mov_start         56.548273  Bio_Motion        2
# 1       Direction  time_of_resp         57.000000  Bio_Motion       17
# 2       Direction     mov_start         68.861094  Bio_Motion        2
# 3       Direction  time_of_resp         77.843091  Bio_Motion        5
# 4       Direction     mov_start         79.935128  Bio_Motion        2
# 5       Direction  time_of_resp         87.417476  Bio_Motion        5
# 6       Direction     mov_start         89.506558  Bio_Motion        2
# 7       Direction  time_of_resp         93.095019  Bio_Motion        5
# 8       Direction     mov_start         95.183875  Bio_Motion        2
# 9       Direction  time_of_resp        103.352262  Bio_Motion        5
# 10      Direction     mov_start        105.444379  Bio_Motion        2
# 11      Direction  time_of_resp        106.000000  Bio_Motion       17
# 12      Direction     mov_start        117.748953  Bio_Motion        1
# 13      Direction  time_of_resp        125.231980  Bio_Motion        4
# 14      Direction     mov_start        127.325483  Bio_Motion        1
# 15      Direction  time_of_resp        132.891453  Bio_Motion        4
# 16      Direction     mov_start        134.983998  Bio_Motion        1
# 17      Direction  time_of_resp        142.166179  Bio_Motion        4
# 18      Direction     mov_start        144.260719  Bio_Motion        2
# 19      Direction  time_of_resp        149.742596  Bio_Motion        5
# 20      Direction     mov_start        151.833465  Bio_Motion        2
# 21      Direction  time_of_resp        152.000000  Bio_Motion       17
# 22      Direction     mov_start        164.174058  Bio_Motion        1
# 23      Direction  time_of_resp        174.086124  Bio_Motion        4
# 24      Direction     mov_start        176.179484  Bio_Motion        2
# 25      Direction  time_of_resp        181.329490  Bio_Motion        5
# 26      Direction     mov_start        183.424132  Bio_Motion        2
# 27      Direction  time_of_resp        188.672495  Bio_Motion        5
# 28      Direction     mov_start        190.765164  Bio_Motion        1
# 29      Direction  time_of_resp        191.000000  Bio_Motion       16
# ..            ...           ...               ...         ...      ...
# 114  Instrumental     mov_start        549.903738  Bio_Motion       11
# 115  Instrumental  time_of_resp        555.128656  Bio_Motion       14
# 116  Instrumental     mov_start        557.229101  Bio_Motion       12
# 117  Instrumental  time_of_resp        564.086901  Bio_Motion       15
# 118  Instrumental     mov_start        566.187527  Bio_Motion       11
# 119  Instrumental  time_of_resp        573.894373  Bio_Motion       14
# 120  Instrumental     mov_start        575.994726  Bio_Motion       12
# 121  Instrumental  time_of_resp        581.570564  Bio_Motion       15
# 122  Instrumental     mov_start        583.672363  Bio_Motion       11
# 123  Instrumental  time_of_resp        584.000000  Bio_Motion       26
# 124  Instrumental     mov_start        595.993272  Bio_Motion       11
# 125  Instrumental  time_of_resp        603.866263  Bio_Motion       14
# 126  Instrumental     mov_start        605.967178  Bio_Motion       11
# 127  Instrumental  time_of_resp        609.594161  Bio_Motion       14
# 128  Instrumental     mov_start        611.694727  Bio_Motion       12
# 129  Instrumental  time_of_resp        614.756070  Bio_Motion       15
# 130  Instrumental     mov_start        616.858576  Bio_Motion       12
# 131  Instrumental  time_of_resp        623.697667  Bio_Motion       15
# 132  Instrumental     mov_start        625.798810  Bio_Motion       11
# 133  Instrumental  time_of_resp        626.000000  Bio_Motion       26
# 134  Instrumental     mov_start        638.135050  Bio_Motion       12
# 135  Instrumental  time_of_resp        639.000000  Bio_Motion       27
# 136  Instrumental     mov_start        650.458377  Bio_Motion       12
# 137  Instrumental  time_of_resp        654.518498  Bio_Motion       15
# 138  Instrumental     mov_start        656.619419  Bio_Motion       11
# 139  Instrumental  time_of_resp        664.275946  Bio_Motion       14
# 140  Instrumental     mov_start        666.376442  Bio_Motion       11
# 141  Instrumental  time_of_resp        667.000000  Bio_Motion       26
# 142  Instrumental     mov_start        678.717931  Bio_Motion       12
# 143  Instrumental  time_of_resp        679.000000  Bio_Motion       27
#
#      trigger_time  trigger_index
# 0        960.9076        1921815
# 1        970.9076        1941815
# 2        973.2204        1946440
# 3        982.2024        1964404
# 4        984.2945        1968588
# 5        991.7768        1983553
# 6        993.8659        1987731
# 7        997.4544        1994908
# 8        999.5432        1999086
# 9       1007.7116        2015423
# 10      1009.8037        2019607
# 11      1019.8037        2039607
# 12      1022.1083        2044216
# 13      1029.5913        2059182
# 14      1031.6848        2063369
# 15      1037.2508        2074501
# 16      1039.3433        2078686
# 17      1046.5255        2093051
# 18      1048.6201        2097240
# 19      1054.1019        2108203
# 20      1056.1928        2112385
# 21      1066.1928        2132385
# 22      1068.5334        2137066
# 23      1078.4455        2156890
# 24      1080.5388        2161077
# 25      1085.6888        2171377
# 26      1087.7835        2175566
# 27      1093.0318        2186063
# 28      1095.1245        2190249
# 29      1105.1245        2210249
# ..            ...            ...
# 114     1454.0065        2908013
# 115     1459.0370        2918074
# 116     1461.3285        2922657
# 117     1467.9865        2935973
# 118     1470.2955        2940591
# 119     1477.7875        2955575
# 120     1480.0635        2960127
# 121     1485.4590        2970917
# 122     1488.0317        2976063
# 123     1497.7740        2995548
# 124     1500.0510        3000102
# 125     1508.2256        3016451
# 126     1509.9970        3019994
# 127     1513.9535        3027906
# 128     1516.0541        3032108
# 129     1519.1154        3038230
# 130     1520.9095        3041819
# 131     1528.0570        3056114
# 132     1529.8145        3059629
# 133     1539.8690        3079738
# 134     1542.4944        3084988
# 135     1552.1810        3104362
# 136     1554.8177        3109635
# 137     1558.8778        3117755
# 138     1560.5975        3121195
# 139     1568.6353        3137270
# 140     1570.3695        3140739
# 141     1580.4280        3160856
# 142     1582.6870        3165374
# 143     1592.7410        3185482
#
# [144 rows x 12 columns]

# %%
bio_dir_evoked_filt
# Out:
# <Evoked  |  comment : 'Direction-Bio/trial_type', kind : average, time : [-1.000000, 4.000000], n_epochs : 18, n_channels x n_times : 32 x 10001, ~2.5 MB>
